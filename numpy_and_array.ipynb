# %%
l = [12, 24, 28, 76, 55, 69, 89, 56]

# %%
import numpy as np
a= np.array(l)

# %%
a
# Out:
# array([12, 24, 28, 76, 55, 69, 89, 56])

# %%
l.pop()
# Out:
# 56

# %%
l
# Out:
# [12, 24, 28, 76, 55, 69, 89]

# %%
b=a.mean()
print(b)
# Out:
# 51.125

# %%
print(l)
# Out:
# [12, 24, 28, 76, 55, 69, 89]

# %%
l[1:]
# Out:
# [24, 28, 76, 55, 69, 89]

# %%
l[:3]
# Out:
# [12, 24, 28]

# %%
l[::2]
# Out:
# [12, 28, 55, 89]

# %%
a
# Out:
# array([12, 24, 28, 76, 55, 69, 89, 56])

# %%
a[2:]
# Out:
# array([28, 76, 55, 69, 89, 56])

# %%
a[:5]
# Out:
# array([12, 24, 28, 76, 55])

# %%
a[::2]
# Out:
# array([12, 28, 55, 89])
